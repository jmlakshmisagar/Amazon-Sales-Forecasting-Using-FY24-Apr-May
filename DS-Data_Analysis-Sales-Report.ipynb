# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/jmlakshmisagar/Desktop/DS/Sales-Report.csv')
# Out:
# /tmp/ipykernel_4112/95527072.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/home/jmlakshmisagar/Desktop/DS/Sales-Report.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-24                     Cancelled
# 1      1  171-9198151-1101146  04-30-24  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-24                       Shipped
# 3      3  403-9615377-8133951  04-30-24                     Cancelled
# 4      4  407-1069790-7240320  04-30-24                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-24  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-24  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-24  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-24  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-24  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %%
df['Date'] = df['Date'].str.replace('-22', '-24')

# %%
df.head(2)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-24                     Cancelled
# 1      1  171-9198151-1101146  04-30-24  Shipped - Delivered to Buyer
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
#
#   Category  ... currency  Amount  ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62     MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00  BENGALURU    KARNATAKA         560085.0
#
#    ship-country                                      promotion-ids    B2B  \
# 0            IN                                                NaN  False
# 1            IN  Amazon PLCC Free-Financing Universal Merchant ...  False
#
#    fulfilled-by Unnamed: 22
# 0     Easy Ship         NaN
# ...

# %%
df.drop(['Order ID','currency','ship-state','ship-country','promotion-ids','fulfilled-by','Unnamed: 22'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    index      Date                        Status Fulfilment Sales Channel   \
# 0      0  04-30-24                     Cancelled   Merchant      Amazon.in
# 1      1  04-30-24  Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2      2  04-30-24                       Shipped     Amazon      Amazon.in
# 3      3  04-30-24                     Cancelled   Merchant      Amazon.in
# 4      4  04-30-24                       Shipped     Amazon      Amazon.in
#
#   ship-service-level    Style              SKU       Category Size  \
# 0           Standard   SET389   SET389-KR-NP-S            Set    S
# 1           Standard  JNE3781  JNE3781-KR-XXXL          kurta  3XL
# 2          Expedited  JNE3371    JNE3371-KR-XL          kurta   XL
# 3           Standard    J0341       J0341-DR-L  Western Dress    L
# 4          Expedited  JNE3671  JNE3671-TU-XXXL            Top  3XL
#
#          ASIN Courier Status  Qty  Amount    ship-city  ship-postal-code  \
# ...

# %%
df.drop(['ASIN'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    index      Date                        Status Fulfilment Sales Channel   \
# 0      0  04-30-24                     Cancelled   Merchant      Amazon.in
# 1      1  04-30-24  Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2      2  04-30-24                       Shipped     Amazon      Amazon.in
# 3      3  04-30-24                     Cancelled   Merchant      Amazon.in
# 4      4  04-30-24                       Shipped     Amazon      Amazon.in
#
#   ship-service-level    Style              SKU       Category Size  \
# 0           Standard   SET389   SET389-KR-NP-S            Set    S
# 1           Standard  JNE3781  JNE3781-KR-XXXL          kurta  3XL
# 2          Expedited  JNE3371    JNE3371-KR-XL          kurta   XL
# 3           Standard    J0341       J0341-DR-L  Western Dress    L
# 4          Expedited  JNE3671  JNE3671-TU-XXXL            Top  3XL
#
#   Courier Status  Qty  Amount    ship-city  ship-postal-code    B2B
# ...

# %%
print(df.columns)
# Out:
# Index(['index', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size',
#        'Courier Status', 'Qty', 'Amount', 'ship-city', 'ship-postal-code',
#        'B2B'],
#       dtype='object')

# %%
df['Sales Channel '].unique()
# Out:
# array(['Amazon.in', 'Non-Amazon'], dtype=object)

# %%
df['Courier Status'].unique()
# Out:
# array([nan, 'Shipped', 'Cancelled', 'Unshipped'], dtype=object)

# %%
df.drop(['Sales Channel '],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    index      Date                        Status Fulfilment  \
# 0      0  04-30-24                     Cancelled   Merchant
# 1      1  04-30-24  Shipped - Delivered to Buyer   Merchant
# 2      2  04-30-24                       Shipped     Amazon
# 3      3  04-30-24                     Cancelled   Merchant
# 4      4  04-30-24                       Shipped     Amazon
# 5      5  04-30-24                       Shipped     Amazon
# 6      6  04-30-24                       Shipped     Amazon
# 7      7  04-30-24  Shipped - Delivered to Buyer   Merchant
# 8      8  04-30-24                     Cancelled     Amazon
# 9      9  04-30-24                       Shipped     Amazon
#
#   ship-service-level    Style                  SKU       Category Size  \
# 0           Standard   SET389       SET389-KR-NP-S            Set    S
# 1           Standard  JNE3781      JNE3781-KR-XXXL          kurta  3XL
# 2          Expedited  JNE3371        JNE3371-KR-XL          kurta   XL
# ...

# %%
df.describe()
# Out:
#                  Qty         Amount  ship-postal-code
# count  128975.000000  121180.000000     128942.000000
# mean        0.904431     648.561465     463966.236509
# std         0.313354     281.211687     191476.764941
# min         0.000000       0.000000     110001.000000
# 25%         1.000000     449.000000     382421.000000
# 50%         1.000000     605.000000     500033.000000
# 75%         1.000000     788.000000     600024.000000
# max        15.000000    5584.000000     989898.000000

# %%
df.drop(['index'],axis=1,inplace=True)

# %%
df['ship-postal-code'].unique()
# Out:
# array([400081., 560085., 410210., ..., 609603., 851205., 629152.])

# %%
df['ship-postal-code'].value_counts()
# Out:
# ship-postal-code
# 201301.0    1006
# 122001.0     688
# 560037.0     632
# 560068.0     619
# 560076.0     581
#             ...
# 144006.0       1
# 829108.0       1
# 263637.0       1
# 815353.0       1
# 629152.0       1
# Name: count, Length: 9459, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                128975 non-null  object
#  1   Status              128975 non-null  object
#  2   Fulfilment          128975 non-null  object
#  3   ship-service-level  128975 non-null  object
#  4   Style               128975 non-null  object
#  5   SKU                 128975 non-null  object
#  6   Category            128975 non-null  object
#  7   Size                128975 non-null  object
#  8   Courier Status      122103 non-null  object
#  9   Qty                 128975 non-null  int64
#  10  Amount              121180 non-null  float64
#  11  ship-city           128942 non-null  object
#  12  ship-postal-code    128942 non-null  float64
#  13  B2B                 128975 non-null  bool
# dtypes: bool(1), float64(2), int64(1), object(10)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                128975 non-null  object
#  1   Status              128975 non-null  object
#  2   Fulfilment          128975 non-null  object
#  3   ship-service-level  128975 non-null  object
#  4   Style               128975 non-null  object
#  5   SKU                 128975 non-null  object
#  6   Category            128975 non-null  object
#  7   Size                128975 non-null  object
#  8   Courier Status      122103 non-null  object
#  9   Qty                 128975 non-null  int64
#  10  Amount              121180 non-null  float64
#  11  ship-city           128942 non-null  object
#  12  ship-postal-code    128975 non-null  int64
#  13  B2B                 128975 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(10)
# ...

# %%
print(df['ship-postal-code'].isnull().sum())
# Out:
# 33

# %%
df['ship-postal-code'] = df['ship-postal-code'].fillna(0)

# %%
df['ship-postal-code'] = df['ship-postal-code'].astype('int64')

# %%
df.describe()
# Out:
#                  Qty         Amount  ship-postal-code
# count  128975.000000  121180.000000     128975.000000
# mean        0.904431     648.561465     463847.524466
# std         0.313354     281.211687     191596.021199
# min         0.000000       0.000000          0.000000
# 25%         1.000000     449.000000     382421.000000
# 50%         1.000000     605.000000     500033.000000
# 75%         1.000000     788.000000     600024.000000
# max        15.000000    5584.000000     989898.000000

# %%
df.head()
# Out:
#        Date                        Status Fulfilment ship-service-level  \
# 0  04-30-24                     Cancelled   Merchant           Standard
# 1  04-30-24  Shipped - Delivered to Buyer   Merchant           Standard
# 2  04-30-24                       Shipped     Amazon          Expedited
# 3  04-30-24                     Cancelled   Merchant           Standard
# 4  04-30-24                       Shipped     Amazon          Expedited
#
#      Style              SKU       Category Size Courier Status  Qty  Amount  \
# 0   SET389   SET389-KR-NP-S            Set    S            NaN    0  647.62
# 1  JNE3781  JNE3781-KR-XXXL          kurta  3XL        Shipped    1  406.00
# 2  JNE3371    JNE3371-KR-XL          kurta   XL        Shipped    1  329.00
# 3    J0341       J0341-DR-L  Western Dress    L            NaN    0  753.33
# 4  JNE3671  JNE3671-TU-XXXL            Top  3XL        Shipped    1  574.00
#
#      ship-city  ship-postal-code    B2B
# ...

# %%
print(max(df['Date']))
# Out:
# 06-29-24

# %%
print(min(df['Date']))
# Out:
# 03-31-24

# %%
df['Date'].describe()
# Out:
# count       128975
# unique          88
# top       04-24-24
# freq          3467
# Name: Date, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')

# %%
df_sorted = df.sort_values(by='Date')

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y', errors='coerce')

# %%
df.head()
# Out:
#         Date                        Status Fulfilment ship-service-level  \
# 0 2024-04-30                     Cancelled   Merchant           Standard
# 1 2024-04-30  Shipped - Delivered to Buyer   Merchant           Standard
# 2 2024-04-30                       Shipped     Amazon          Expedited
# 3 2024-04-30                     Cancelled   Merchant           Standard
# 4 2024-04-30                       Shipped     Amazon          Expedited
#
#      Style              SKU       Category Size Courier Status  Qty  Amount  \
# 0   SET389   SET389-KR-NP-S            Set    S            NaN    0  647.62
# 1  JNE3781  JNE3781-KR-XXXL          kurta  3XL        Shipped    1  406.00
# 2  JNE3371    JNE3371-KR-XL          kurta   XL        Shipped    1  329.00
# 3    J0341       J0341-DR-L  Western Dress    L            NaN    0  753.33
# 4  JNE3671  JNE3671-TU-XXXL            Top  3XL        Shipped    1  574.00
#
#      ship-city  ship-postal-code    B2B
# ...

# %%
df_sorted = df.sort_values(by='Date')

# %%
df_sorted = df_sorted.reset_index(drop=True)

# %%
df.head()
# Out:
#         Date                        Status Fulfilment ship-service-level  \
# 0 2024-04-30                     Cancelled   Merchant           Standard
# 1 2024-04-30  Shipped - Delivered to Buyer   Merchant           Standard
# 2 2024-04-30                       Shipped     Amazon          Expedited
# 3 2024-04-30                     Cancelled   Merchant           Standard
# 4 2024-04-30                       Shipped     Amazon          Expedited
#
#      Style              SKU       Category Size Courier Status  Qty  Amount  \
# 0   SET389   SET389-KR-NP-S            Set    S            NaN    0  647.62
# 1  JNE3781  JNE3781-KR-XXXL          kurta  3XL        Shipped    1  406.00
# 2  JNE3371    JNE3371-KR-XL          kurta   XL        Shipped    1  329.00
# 3    J0341       J0341-DR-L  Western Dress    L            NaN    0  753.33
# 4  JNE3671  JNE3671-TU-XXXL            Top  3XL        Shipped    1  574.00
#
#      ship-city  ship-postal-code    B2B
# ...

# %%
print(min(df['Date']))
# Out:
# 2024-03-31 00:00:00

# %%
print(max(df['Date']))
# Out:
# 2024-06-29 00:00:00

# %%
print(df['Date'].unique())
# Out:
# <DatetimeArray>
# ['2024-04-30 00:00:00', '2024-04-29 00:00:00', '2024-04-28 00:00:00',
#  '2024-04-27 00:00:00', '2024-04-26 00:00:00', '2024-04-25 00:00:00',
#  '2024-04-24 00:00:00', '2024-04-23 00:00:00', '2024-04-21 00:00:00',
#  '2024-04-20 00:00:00', '2024-04-19 00:00:00', '2024-04-18 00:00:00',
#  '2024-04-17 00:00:00', '2024-04-16 00:00:00', '2024-04-15 00:00:00',
#  '2024-04-14 00:00:00', '2024-04-13 00:00:00', '2024-04-12 00:00:00',
#  '2024-04-11 00:00:00', '2024-04-10 00:00:00', '2024-04-09 00:00:00',
#  '2024-04-08 00:00:00', '2024-04-07 00:00:00', '2024-04-06 00:00:00',
#  '2024-04-05 00:00:00', '2024-04-04 00:00:00', '2024-04-03 00:00:00',
#  '2024-04-02 00:00:00', '2024-04-01 00:00:00', '2024-03-31 00:00:00',
#  '2024-05-31 00:00:00', '2024-05-30 00:00:00', '2024-05-29 00:00:00',
#  '2024-05-28 00:00:00', '2024-05-27 00:00:00', '2024-05-26 00:00:00',
#  '2024-05-25 00:00:00', '2024-05-24 00:00:00', '2024-05-23 00:00:00',
# ...

# %%
df['Date'].describe()
# Out:
# count                           128975
# mean     2024-05-12 13:22:41.594107648
# min                2024-03-31 00:00:00
# 25%                2024-04-20 00:00:00
# 50%                2024-05-10 00:00:00
# 75%                2024-06-04 00:00:00
# max                2024-06-29 00:00:00
# Name: Date, dtype: object

# %%
df_sorted = df.sort_values(by='Date')

# %%
df_sorted = df_sorted.reset_index(drop=True)

# %%
print(df_sorted.head())
# Out:
#         Date                        Status Fulfilment ship-service-level  \
# 0 2024-03-31  Shipped - Delivered to Buyer   Merchant           Standard
# 1 2024-03-31                       Shipped     Amazon          Expedited
# 2 2024-03-31                     Cancelled   Merchant           Standard
# 3 2024-03-31                       Shipped     Amazon          Expedited
# 4 2024-03-31                       Shipped     Amazon          Expedited
#
#      Style              SKU Category Size Courier Status  Qty  Amount  \
# 0  JNE3724     JNE3724-KR-L    kurta    L        Shipped    1  495.00
# 1   SET187  SET187-KR-DH-XL      Set   XL        Shipped    1  599.00
# 2  JNE3383   JNE3383-KR-A-M    kurta    M            NaN    0  416.19
# 3  JNE3405     JNE3405-KR-L    kurta    L        Shipped    1  449.00
# 4   SET044   SET044-KR-NP-L      Set    L        Shipped    1  542.00
#
#          ship-city  ship-postal-code    B2B
# 0          KOLKATA            700124  False
# ...

# %%
df = df_sorted

# %%
df.head()
# Out:
#         Date                        Status Fulfilment ship-service-level  \
# 0 2024-03-31  Shipped - Delivered to Buyer   Merchant           Standard
# 1 2024-03-31                       Shipped     Amazon          Expedited
# 2 2024-03-31                     Cancelled   Merchant           Standard
# 3 2024-03-31                       Shipped     Amazon          Expedited
# 4 2024-03-31                       Shipped     Amazon          Expedited
#
#      Style              SKU Category Size Courier Status  Qty  Amount  \
# 0  JNE3724     JNE3724-KR-L    kurta    L        Shipped    1  495.00
# 1   SET187  SET187-KR-DH-XL      Set   XL        Shipped    1  599.00
# 2  JNE3383   JNE3383-KR-A-M    kurta    M            NaN    0  416.19
# 3  JNE3405     JNE3405-KR-L    kurta    L        Shipped    1  449.00
# 4   SET044   SET044-KR-NP-L      Set    L        Shipped    1  542.00
#
#          ship-city  ship-postal-code    B2B
# 0          kolkata            700124  False
# ...

# %%
df['ship-city'] = df['ship-city'].str.lower()

# %%
df['ship-city'].describe()
# Out:
# count        128942
# unique         7297
# top       bengaluru
# freq          11898
# Name: ship-city, dtype: object

# %%
df['ship-city'].value_counts()
# Out:
# ship-city
# bengaluru                  11898
# hyderabad                   9125
# mumbai                      7122
# new delhi                   6340
# chennai                     6284
#                            ...
# kewalpur bahraich              1
# virar w                        1
# nadakkavu                      1
# kalasalingam university        1
# manalurpet                     1
# Name: count, Length: 7297, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Date', 'Status', 'Fulfilment', 'ship-service-level', 'Style', 'SKU',
#        'Category', 'Size', 'Courier Status', 'Qty', 'Amount', 'ship-city',
#        'ship-postal-code', 'B2B'],
#       dtype='object')

# %%
df['ship-service-level']=df['ship-service-level'].str.lower()

# %%
df['Courier Status']=df['Courier Status'].str.lower()

# %%
df['Size']=df['Size'].str.upper()

# %%
df.head()
# Out:
#         Date                        Status Fulfilment ship-service-level  \
# 0 2024-03-31  Shipped - Delivered to Buyer   Merchant           standard
# 1 2024-03-31                       Shipped     Amazon          expedited
# 2 2024-03-31                     Cancelled   Merchant           standard
# 3 2024-03-31                       Shipped     Amazon          expedited
# 4 2024-03-31                       Shipped     Amazon          expedited
#
#      Style              SKU Category Size Courier Status  Qty  Amount  \
# 0  JNE3724     JNE3724-KR-L    kurta    L        shipped    1  495.00
# 1   SET187  SET187-KR-DH-XL      Set   XL        shipped    1  599.00
# 2  JNE3383   JNE3383-KR-A-M    kurta    M            NaN    0  416.19
# 3  JNE3405     JNE3405-KR-L    kurta    L        shipped    1  449.00
# 4   SET044   SET044-KR-NP-L      Set    L        shipped    1  542.00
#
#          ship-city  ship-postal-code    B2B
# 0          kolkata            700124  False
# ...

# %%
df['Category']=df['Category'].str.lower()

# %%
df['Courier Status'].value_counts()
# Out:
# Courier Status
# shipped      109487
# unshipped      6681
# cancelled      5935
# Name: count, dtype: int64

# %%
df
# Out:
#              Date                        Status Fulfilment ship-service-level  \
# 0      2024-03-31  Shipped - Delivered to Buyer   Merchant           standard
# 1      2024-03-31                       Shipped     Amazon          expedited
# 2      2024-03-31                     Cancelled   Merchant           standard
# 3      2024-03-31                       Shipped     Amazon          expedited
# 4      2024-03-31                       Shipped     Amazon          expedited
# ...           ...                           ...        ...                ...
# 128970 2024-06-29                       Pending     Amazon          expedited
# 128971 2024-06-29                       Shipped     Amazon          expedited
# 128972 2024-06-29                       Pending     Amazon          expedited
# 128973 2024-06-29                       Pending   Merchant           standard
# 128974 2024-06-29                       Pending     Amazon          expedited
#
# ...

# %%
df['Status']=df['Status'].str.lower()

# %%
df['Qty'].value_counts()
# Out:
# Qty
# 1     115780
# 0      12807
# 2        341
# 3         32
# 4          9
# 5          2
# 8          1
# 13         1
# 9          1
# 15         1
# Name: count, dtype: int64

# %%
changeee={'False':0,'True':1}
df['B2B']=df['B2B'].replace(changeee)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                128975 non-null  datetime64[ns]
#  1   Status              128975 non-null  object
#  2   Fulfilment          128975 non-null  object
#  3   ship-service-level  128975 non-null  object
#  4   Style               128975 non-null  object
#  5   SKU                 128975 non-null  object
#  6   Category            128975 non-null  object
#  7   Size                128975 non-null  object
#  8   Courier Status      122103 non-null  object
#  9   Qty                 128975 non-null  int64
#  10  Amount              121180 non-null  float64
#  11  ship-city           128942 non-null  object
#  12  ship-postal-code    128975 non-null  int64
#  13  B2B                 128975 non-null  bool
# ...

# %%
df
# Out:
#              Date                        Status Fulfilment ship-service-level  \
# 0      2024-03-31  shipped - delivered to buyer   Merchant           standard
# 1      2024-03-31                       shipped     Amazon          expedited
# 2      2024-03-31                     cancelled   Merchant           standard
# 3      2024-03-31                       shipped     Amazon          expedited
# 4      2024-03-31                       shipped     Amazon          expedited
# ...           ...                           ...        ...                ...
# 128970 2024-06-29                       pending     Amazon          expedited
# 128971 2024-06-29                       shipped     Amazon          expedited
# 128972 2024-06-29                       pending     Amazon          expedited
# 128973 2024-06-29                       pending   Merchant           standard
# 128974 2024-06-29                       pending     Amazon          expedited
#
# ...

# %%
df['B2B'] = df['B2B'].astype(int)

# %%
df['B2B'].value_counts()
# Out:
# B2B
# 0    128104
# 1       871
# Name: count, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Category
# set              50284
# kurta            49877
# western dress    15500
# top              10622
# ethnic dress      1159
# blouse             926
# bottom             440
# saree              164
# dupatta              3
# Name: count, dtype: int64

# %%
df.to_csv('explicit-dataset')
