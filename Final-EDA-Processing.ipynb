# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/jmlakshmisagar/Desktop/DS/final-report.csv')

# %%
df.head(10)
# Out:
#          Date                        Status Fulfilment ship-service-level  \
# 0  2024-03-31  shipped - delivered to buyer   Merchant           standard
# 1  2024-03-31                       shipped     Amazon          expedited
# 2  2024-03-31                       shipped     Amazon          expedited
# 3  2024-03-31                       shipped     Amazon          expedited
# 4  2024-03-31                       shipped     Amazon          expedited
# 5  2024-03-31                       shipped     Amazon          expedited
# 6  2024-03-31                       shipped     Amazon          expedited
# 7  2024-03-31                       shipped     Amazon          expedited
# 8  2024-03-31                       shipped     Amazon          expedited
# 9  2024-03-31                       shipped     Amazon          expedited
#
#      Style              SKU Category Size Courier Status  Qty  Amount  \
# 0  JNE3724     JNE3724-KR-L    kurta    L        shipped    1   495.0
# 1   SET187  SET187-KR-DH-XL      set   XL        shipped    1   599.0
# 2  JNE3405     JNE3405-KR-L    kurta    L        shipped    1   449.0
# 3   SET044   SET044-KR-NP-L      set    L        shipped    1   542.0
# 4    J0345      J0345-SET-M      set    M        shipped    1   519.0
# 5   SET366   SET366-KR-NP-S      set    S        shipped    1  1165.0
# 6    J0132       J0132-KR-L    kurta    L        shipped    1   358.0
# 7  JNE3607   JNE3607-KR-XXL    kurta  XXL        shipped    1   417.0
# 8    J0003      J0003-SET-M      set    M        shipped    1   688.0
# 9   SET345   SET345-KR-NP-L      set    L        shipped    1   657.0
#
#          ship-city
# 0          kolkata
# 1        bengaluru
# 2  nalasopara east
# 3        hyderabad
# 4        bengaluru
# 5         bhiwandi
# 6            patna
# 7         vadodara
# 8           ongole
# 9         vadodara

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115190 entries, 0 to 115189
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                115190 non-null  object
#  1   Status              115190 non-null  object
#  2   Fulfilment          115190 non-null  object
#  3   ship-service-level  115190 non-null  object
#  4   Style               115190 non-null  object
#  5   SKU                 115190 non-null  object
#  6   Category            115190 non-null  object
#  7   Size                115190 non-null  object
#  8   Courier Status      115190 non-null  object
#  9   Qty                 115190 non-null  int64
#  10  Amount              115190 non-null  float64
#  11  ship-city           115162 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 10.5+ MB

# %%
df['ship-service-level'].describe()
# Out:
# count        115190
# unique            2
# top       expedited
# freq          82023
# Name: ship-service-level, dtype: object

# %%
df['ship-service-level'].value_counts()
# Out:
# ship-service-level
# expedited    82023
# standard     33167
# Name: count, dtype: int64

# %%
sns.countplot(x='ship-service-level',data=df)
# Out:
# <AxesSubplot: xlabel='ship-service-level', ylabel='count'>

# %%
sns.scatterplot(x='ship-service-level',y='Amount',data=df)
# Out:
# <AxesSubplot: xlabel='ship-service-level', ylabel='Amount'>

# %%
fil_data = df[(df['ship-city']=='bengaluru')]

# %%
sns.boxplot(x='ship-service-level',y='ship-city',data=fil_data)
# Out:
# <AxesSubplot: xlabel='ship-service-level', ylabel='ship-city'>

# %%
df['Style'].describe()
# Out:
# count      115190
# unique       1371
# top       JNE3797
# freq         3651
# Name: Style, dtype: object

# %%
df['Style'].value_counts()
# Out:
# Style
# JNE3797    3651
# JNE3405    2016
# SET268     1697
# J0230      1679
# J0341      1447
#            ...
# BL060         1
# JNE3362       1
# SET162        1
# BL074         1
# SET019        1
# Name: count, Length: 1371, dtype: int64

# %%
plt.figure(figsize=(10, 15))
sns.countplot(y='Status', data=df)
plt.title('Distribution of Status')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115190 entries, 0 to 115189
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                115190 non-null  object
#  1   Status              115190 non-null  object
#  2   Fulfilment          115190 non-null  object
#  3   ship-service-level  115190 non-null  object
#  4   Style               115190 non-null  object
#  5   SKU                 115190 non-null  object
#  6   Category            115190 non-null  object
#  7   Size                115190 non-null  object
#  8   Courier Status      115190 non-null  object
#  9   Qty                 115190 non-null  int64
#  10  Amount              115190 non-null  float64
#  11  ship-city           115162 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 10.5+ MB

# %%
plt.figure(figsize=(10, 15))
sns.violinplot(y='Status', data=df)
plt.title('Distribution of Status')
plt.show()
